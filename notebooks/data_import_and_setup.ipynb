# %%
import pandas as pd
import geopandas as gpd
import duckdb

# %%
con = duckdb.connect("seattle.db")

# %%
con.install_extension("spatial")
con.

# %%
#import csv
df = pd.read_csv('../data/csv/socio-economic-factors_20220905.csv')
#select only geo_fip, population_density and Median Household Income (In 2019 Inflation Adjusted Dollars)
df = df[['Geo_FIPS', 'Population Density (Per Sq. Mile)', 'Median Household Income (In 2019 Inflation Adjusted Dollars)']]
#rename columns to GEOID10, pop_density and median_income
df = df.rename(columns={'Geo_FIPS': 'GEOID10', 'Population Density (Per Sq. Mile)': 'pop_density', 'Median Household Income (In 2019 Inflation Adjusted Dollars)': 'median_income'})
# drop null values
df = df.dropna()
#convert GEOID10 to int
df['GEOID10'] = df['GEOID10'].astype(int)
df
# Out:
#           GEOID10  pop_density  median_income
# 0    530330001001     3708.992       206400.0
# 1    530330001002    14342.320        50714.0
# 2    530330001003    10101.800        51397.0
# 3    530330001004    51934.570        42150.0
# 4    530330001005    15089.690        47292.0
# ..            ...          ...            ...
# 475  530330121001     3758.872       140400.0
# 476  530330121002     4571.933       117727.0
# 479  530330260011     5680.552       104469.0
# 480  530330264004     2000.136        62188.0
# 481  530330264005     5176.891        55761.0
#
# [468 rows x 3 columns]

# %%
#load shapefile
bg = gpd.read_file('../data/shapefiles/Census_Block_Groups_2010/Census_Block_Groups_2010.shp')
#select columns GEOID, geometry
bg = bg[['GEOID10', 'geometry']]
#convert GEOID10 to int
bg['GEOID10'] = bg['GEOID10'].astype(int)
bg
# Out:
#           GEOID10                                           geometry
# 0    530330001001  POLYGON ((-122.26840 47.72641, -122.26719 47.7...
# 1    530330001002  POLYGON ((-122.28970 47.73193, -122.28965 47.7...
# 2    530330001003  POLYGON ((-122.28633 47.72093, -122.28629 47.7...
# 3    530330001004  POLYGON ((-122.29237 47.73194, -122.29231 47.7...
# 4    530330001005  POLYGON ((-122.29273 47.72019, -122.29273 47.7...
# ..            ...                                                ...
# 477  530330117003  POLYGON ((-122.28084 47.52520, -122.28082 47.5...
# 478  530330117004  POLYGON ((-122.27932 47.52258, -122.27954 47.5...
# 479  530330118001  POLYGON ((-122.26232 47.53173, -122.24933 47.5...
# 480  530330118002  POLYGON ((-122.25464 47.51692, -122.25455 47.5...
# 481  530330118003  POLYGON ((-122.26158 47.52026, -122.26160 47.5...
#
# [482 rows x 2 columns]

# %%
# merge the two dataframes
gdf= bg.merge(df, on='GEOID10')
gdf
# Out:
#           GEOID10                                           geometry  \
# 0    530330001001  POLYGON ((-122.26840 47.72641, -122.26719 47.7...
# 1    530330001002  POLYGON ((-122.28970 47.73193, -122.28965 47.7...
# 2    530330001003  POLYGON ((-122.28633 47.72093, -122.28629 47.7...
# 3    530330001004  POLYGON ((-122.29237 47.73194, -122.29231 47.7...
# 4    530330001005  POLYGON ((-122.29273 47.72019, -122.29273 47.7...
# ..            ...                                                ...
# 463  530330117002  POLYGON ((-122.28750 47.52489, -122.28732 47.5...
# 464  530330117003  POLYGON ((-122.28084 47.52520, -122.28082 47.5...
# 465  530330117004  POLYGON ((-122.27932 47.52258, -122.27954 47.5...
# 466  530330118001  POLYGON ((-122.26232 47.53173, -122.24933 47.5...
# 467  530330118003  POLYGON ((-122.26158 47.52026, -122.26160 47.5...
#
#      pop_density  median_income
# 0       3708.992       206400.0
# 1      14342.320        50714.0
# 2      10101.800        51397.0
# 3      51934.570        42150.0
# 4      15089.690        47292.0
# ..           ...            ...
# 463     2603.928        84886.0
# 464     6885.910        91583.0
# 465     2112.793        72639.0
# 466     5266.039       105667.0
# 467     8307.381        97703.0
#
# [468 rows x 4 columns]

# %%
#visulize the data
gdf.explore(tiles = 'cartodbpositron', column ='median_income', cmap='GnBu_r', scheme='natural_breaks', k=10, legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f190d0bbb64b3a380469458b0e88852 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f190d0bbb64b3a380469458b0e88852&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f190d0bbb64b3a380469458b0e88852 = L.map(
#                 &quot;map_5f190d0bbb64b3a380469458b0e88852&quot;,
#                 {
#                     center: [47.6136757489171, -122.32493247249751],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5f190d0bbb64b3a380469458b0e88852);
#
#
#
#
#
#             var tile_layer_d3a81176354358bd1c5c49f82d8ae6b7 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f190d0bbb64b3a380469458b0e88852);
#
#
#             map_5f190d0bbb64b3a380469458b0e88852.fitBounds(
#                 [[47.493204794985786, -122.42543411479825], [47.73414670284841, -122.22443083019677]],
#                 {}
#             );
#
#
#         function geo_json_28350b3f73689d7b193d0f5c6d4c0ee0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;139&quot;: case &quot;142&quot;: case &quot;223&quot;: case &quot;225&quot;: case &quot;229&quot;: case &quot;266&quot;: case &quot;453&quot;:
#                     return {&quot;color&quot;: &quot;#f7fcf0&quot;, &quot;fillColor&quot;: &quot;#f7fcf0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;16&quot;: case &quot;24&quot;: case &quot;26&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;42&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;47&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;148&quot;: case &quot;212&quot;: case &quot;252&quot;: case &quot;263&quot;: case &quot;281&quot;: case &quot;285&quot;: case &quot;291&quot;: case &quot;294&quot;: case &quot;295&quot;: case &quot;297&quot;: case &quot;306&quot;: case &quot;309&quot;: case &quot;322&quot;: case &quot;349&quot;: case &quot;354&quot;: case &quot;355&quot;: case &quot;368&quot;: case &quot;373&quot;: case &quot;403&quot;: case &quot;407&quot;: case &quot;408&quot;: case &quot;409&quot;: case &quot;410&quot;: case &quot;415&quot;: case &quot;419&quot;: case &quot;420&quot;: case &quot;421&quot;: case &quot;422&quot;: case &quot;424&quot;: case &quot;437&quot;: case &quot;440&quot;: case &quot;441&quot;:
#                     return {&quot;color&quot;: &quot;#0864a7&quot;, &quot;fillColor&quot;: &quot;#0864a7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;38&quot;: case &quot;41&quot;: case &quot;62&quot;: case &quot;65&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;79&quot;: case &quot;86&quot;: case &quot;89&quot;: case &quot;95&quot;: case &quot;97&quot;: case &quot;103&quot;: case &quot;106&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;113&quot;: case &quot;124&quot;: case &quot;131&quot;: case &quot;144&quot;: case &quot;150&quot;: case &quot;154&quot;: case &quot;158&quot;: case &quot;159&quot;: case &quot;163&quot;: case &quot;168&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;199&quot;: case &quot;202&quot;: case &quot;214&quot;: case &quot;220&quot;: case &quot;222&quot;: case &quot;227&quot;: case &quot;236&quot;: case &quot;242&quot;: case &quot;247&quot;: case &quot;253&quot;: case &quot;280&quot;: case &quot;282&quot;: case &quot;300&quot;: case &quot;302&quot;: case &quot;305&quot;: case &quot;317&quot;: case &quot;328&quot;: case &quot;331&quot;: case &quot;333&quot;: case &quot;335&quot;: case &quot;336&quot;: case &quot;341&quot;: case &quot;356&quot;: case &quot;357&quot;: case &quot;360&quot;: case &quot;375&quot;: case &quot;378&quot;: case &quot;383&quot;: case &quot;386&quot;: case &quot;431&quot;: case &quot;434&quot;: case &quot;451&quot;: case &quot;454&quot;: case &quot;456&quot;: case &quot;458&quot;:

# %%
#save gdf to shapefile, make directory if it does not exist
import os
if not os.path.exists('../data/shapefiles/seattle'):
    os.makedirs('../data/shapefiles/seattle')
gdf.to_file('../data/shapefiles/seattle/seattle.shp')
# Out:
# /var/folders/zm/x5dzdlrs5mlbxrm7z5g6p05r0000gn/T/ipykernel_22124/701296342.py:5: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file('../data/shapefiles/seattle/seattle.shp')

# %%
#connect to duckdb
con = duckdb.connect(database='../data/my_spatial_db.duckdb', read_only=False)

# %%
#install the spatial extension
con.install_extension("spatial")
con.load_extension("spatial")

# %%
#read the shapefile into duckdb
con.sql("SELECT * FROM ST_Read('../data/shapefiles/seattle/seattle.shp')")
# Out:
# ┌──────────────┬───────────────────┬────────────┬──────────────────────────────────────────────────────────────────────┐
# │   GEOID10    │    pop_densit     │ median_inc │                                 geom                                 │
# │    int64     │      double       │   double   │                               geometry                               │
# ├──────────────┼───────────────────┼────────────┼──────────────────────────────────────────────────────────────────────┤
# │ 530330001001 │          3708.992 │   206400.0 │ POLYGON ((-122.26839878436476 47.726405904524746, -122.26719075207…  │
# │ 530330001002 │          14342.32 │    50714.0 │ POLYGON ((-122.28970480907557 47.73193185821239, -122.289654800872…  │
# │ 530330001003 │           10101.8 │    51397.0 │ POLYGON ((-122.28632675942778 47.7209318679193, -122.2862897518206…  │
# │ 530330001004 │          51934.57 │    42150.0 │ POLYGON ((-122.29237280801134 47.731942852365506, -122.29231180027…  │
# │ 530330001005 │          15089.69 │    47292.0 │ POLYGON ((-122.29272875587536 47.7201938542405, -122.292729752911 …  │
# │ 530330002001 │          8681.742 │   115500.0 │ POLYGON ((-122.29638177642876 47.72470384603186, -122.296358768373…  │
# │ 530330002002 │          6931.416 │    67043.0 │ POLYGON ((-122.29913677707518 47.724726839963985, -122.29912076805…  │
# │ 530330002003 │          4965.254 │    59570.0 │ POLYGON ((-122.31267479292362 47.72845881046642, -122.312650785568…  │
# │ 530330002004 │          7331.845 │    85964.0 │ POLYGON ((-122.30724178671069 47.72690182212021, -122.307235784398…  │
# │ 530330002005 │          8966.982 │    89821.0 │ POLYGON ((-122.3154567847711 47.72664380478482, -122.3141427855728…  │
# │       ·      │              ·    │       ·    │                                  ·                                   │
# │       ·      │              ·    │       ·    │                                  ·                                   │
# │       ·      │              ·    │       ·    │                                  ·                                   │
# │ 530330116002 │          8063.864 │   114706.0 │ POLYGON ((-122.38201190697805 47.52914877949873, -122.382019903643…  │
# │ 530330116003 │ 6974.468000000001 │   124779.0 │ POLYGON ((-122.38996590595356 47.5288927697914, -122.3897439063740…  │
# │ 530330116004 │          3600.295 │   134519.0 │ POLYGON ((-122.3793878790066 47.52288778667502, -122.3794398712344…  │
# │ 530330116005 │ 7866.880999999999 │   118365.0 │ POLYGON ((-122.39177686578007 47.51974377385984, -122.392560864813…  │
# │ 530330116006 │          2565.805 │   119118.0 │ POLYGON ((-122.39583095586568 47.54020175550069, -122.395379955636…  │
# │ 530330117002 │          2603.928 │    84886.0 │ POLYGON ((-122.28749588809818 47.52488889807891, -122.287320887844…  │
# │ 530330117003 │           6885.91 │    91583.0 │ POLYGON ((-122.28084189034149 47.52519690596636, -122.280817886142…  │
# │ 530330117004 │          2112.793 │    72639.0 │ POLYGON ((-122.27932287848351 47.5225759080294, -122.2795398749176…  │
# │ 530330118001 │ 5266.039000000001 │   105667.0 │ POLYGON ((-122.26231591846823 47.53172892769246, -122.249330919681…  │
# │ 530330118003 │          8307.381 │    97703.0 │ POLYGON ((-122.26158186822076 47.52026392946155, -122.261598863026…  │
# ├──────────────┴───────────────────┴────────────┴──────────────────────────────────────────────────────────────────────┤
# │ 468 rows (20 shown)                                                                                        4 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
con.sql(
    """
        CREATE TABLE IF NOT EXISTS seattle_pop_income AS 
        SELECT * FROM ST_Read('../data/shapefiles/seattle/seattle.shp')
        """
)

# %%
#create a new table
con.table('seattle_pop_income')
# Out:
# ┌──────────────┬───────────────────┬────────────┬──────────────────────────────────────────────────────────────────────┐
# │   GEOID10    │    pop_densit     │ median_inc │                                 geom                                 │
# │    int64     │      double       │   double   │                               geometry                               │
