# %%
import pandas as pd
import geopandas as gpd

# %%
# read in the data user study/ accessbile_map.log.json
df = pd.read_json('../data/user-study/accessible_map.logs_user6.json')

# %%
df
# Out:
#                                       _id  \
# 0    {'$oid': '662bcf3f440e50a0685328e8'}
# 1    {'$oid': '662bcf40440e50a0685328e9'}
# 2    {'$oid': '662bcf40440e50a0685328ea'}
# 3    {'$oid': '662bcf41440e50a0685328eb'}
# 4    {'$oid': '662bcf41440e50a0685328ec'}
# ..                                    ...
# 176  {'$oid': '662bd9ce440e50a068532998'}
# 177  {'$oid': '662bd9cf440e50a068532999'}
# 178  {'$oid': '662bd9d4440e50a06853299a'}
# 179  {'$oid': '662bdd061a4ee37ee22d2ae4'}
# 180  {'$oid': '662bdd101a4ee37ee22d2ae5'}
#
#                                      uuid user_id  \
# 0    28b3af64-c1a8-417b-9d76-f60b6cd3fe68   user6
# 1    9feb60b1-a421-412b-b2a5-01c9a59b6bb1   user6
# 2    ea1a34a6-2e43-41c5-b75a-5dc61686931e   user6
# 3    78fc77a2-e62f-44d0-a6e8-4b09a7519eac   user6
# 4    ebe273e1-c91c-43d4-ae12-b5a039462d73   user6
# ..                                    ...     ...
# 176  daf4e30c-4c09-48eb-852d-ef3510a679e3   user6
# ...

# %%
print(df['session_id'].unique())
# Out:
# ['e91048f9-ba7d-479f-bd2d-5a40d79d301f'
#  '5ad4fd94-d514-42dc-8179-2c38e52a3571'
#  'c56bb4c4-d024-4ebe-aaf5-2ab8fd7e68c1']

# %%
#add a new column to convert the timestamp to a PST
df['timestamp_pst'] = pd.to_datetime(df['timestamp'])
df['timestamp_pst'] = df['timestamp'].dt.tz_convert('America/Los_Angeles')

# %%
df
# Out:
#                                       _id  \
# 0    {'$oid': '662bcf3f440e50a0685328e8'}
# 1    {'$oid': '662bcf40440e50a0685328e9'}
# 2    {'$oid': '662bcf40440e50a0685328ea'}
# 3    {'$oid': '662bcf41440e50a0685328eb'}
# 4    {'$oid': '662bcf41440e50a0685328ec'}
# ..                                    ...
# 176  {'$oid': '662bd9ce440e50a068532998'}
# 177  {'$oid': '662bd9cf440e50a068532999'}
# 178  {'$oid': '662bd9d4440e50a06853299a'}
# 179  {'$oid': '662bdd061a4ee37ee22d2ae4'}
# 180  {'$oid': '662bdd101a4ee37ee22d2ae5'}
#
#                                      uuid user_id  \
# 0    28b3af64-c1a8-417b-9d76-f60b6cd3fe68   user6
# 1    9feb60b1-a421-412b-b2a5-01c9a59b6bb1   user6
# 2    ea1a34a6-2e43-41c5-b75a-5dc61686931e   user6
# 3    78fc77a2-e62f-44d0-a6e8-4b09a7519eac   user6
# 4    ebe273e1-c91c-43d4-ae12-b5a039462d73   user6
# ..                                    ...     ...
# 176  daf4e30c-4c09-48eb-852d-ef3510a679e3   user6
# ...

# %%
# sort by timestamp PST 
df.sort_values(by='timestamp_pst').head(50)
# Out:
#                                      _id  \
# 0   {'$oid': '662bcf3f440e50a0685328e8'}
# 1   {'$oid': '662bcf40440e50a0685328e9'}
# 2   {'$oid': '662bcf40440e50a0685328ea'}
# 3   {'$oid': '662bcf41440e50a0685328eb'}
# 4   {'$oid': '662bcf41440e50a0685328ec'}
# 5   {'$oid': '662bcf41440e50a0685328ed'}
# 6   {'$oid': '662bcf42440e50a0685328ee'}
# 7   {'$oid': '662bcf42440e50a0685328ef'}
# 8   {'$oid': '662bcf42440e50a0685328f0'}
# 9   {'$oid': '662bcfe2440e50a0685328f1'}
# 10  {'$oid': '662bcfe4440e50a0685328f2'}
# 11  {'$oid': '662bcfe7440e50a0685328f3'}
# 12  {'$oid': '662bcfe8440e50a0685328f4'}
# 13  {'$oid': '662bd002440e50a0685328f5'}
# 14  {'$oid': '662bd008440e50a0685328f6'}
# 15  {'$oid': '662bd012440e50a0685328f7'}
# 16  {'$oid': '662bd017440e50a0685328f8'}
# 17  {'$oid': '662bd02a440e50a0685328f9'}
# 18  {'$oid': '662bd02c440e50a0685328fa'}
# 19  {'$oid': '662bd037440e50a0685328fb'}
# 20  {'$oid': '662bd03e440e50a0685328fc'}
# 21  {'$oid': '662bd1ed440e50a0685328fd'}
# ...

# %%
#select all the dat
p1_tutorial = df[df['session_id'] == '5ad4fd94-d514-42dc-8179-2c38e52a3571']

# %%
p1_tutorial
# Out:
#                                      _id  \
# 9   {'$oid': '662bcfe2440e50a0685328f1'}
# 10  {'$oid': '662bcfe4440e50a0685328f2'}
# 11  {'$oid': '662bcfe7440e50a0685328f3'}
# 12  {'$oid': '662bcfe8440e50a0685328f4'}
# 13  {'$oid': '662bd002440e50a0685328f5'}
# ..                                   ...
# 81  {'$oid': '662bd4a9440e50a068532939'}
# 82  {'$oid': '662bd528440e50a06853293a'}
# 83  {'$oid': '662bd534440e50a06853293b'}
# 84  {'$oid': '662bd54e440e50a06853293c'}
# 85  {'$oid': '662bd54e440e50a06853293d'}
#
#                                     uuid user_id  \
# 9   8a304837-6f24-4f0c-82f4-cbf9b1e671d0   user6
# 10  10537ee4-760c-4b87-8c80-7b7e18a2fde4   user6
# 11  55cd8f81-497c-467a-9aab-1520bb78ad09   user6
# 12  5aa623ba-23a6-48ad-a1e6-978371aef43f   user6
# 13  041b310e-3ca9-4e4c-acd1-06b6ab7b4c48   user6
# ..                                   ...     ...
# 81  4dc1ab21-064f-4527-a795-29a635c04784   user6
# 82  45992094-3127-46a8-b6c3-11431e31139b   user6
# ...

# %%
#change user_id to user1
p1_tutorial['user_id'] = 'user1'
# Out:
# /var/folders/zm/x5dzdlrs5mlbxrm7z5g6p05r0000gn/T/ipykernel_33295/2283412184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p1_tutorial['user_id'] = 'user1'

# %%
#save the data to a csv file
p1_tutorial.to_csv('../data/user-study/processed/p1_tutorial.csv')

# %%
df
# Out:
#                                       _id  \
# 0    {'$oid': '662bcf3f440e50a0685328e8'}
# 1    {'$oid': '662bcf40440e50a0685328e9'}
# 2    {'$oid': '662bcf40440e50a0685328ea'}
# 3    {'$oid': '662bcf41440e50a0685328eb'}
# 4    {'$oid': '662bcf41440e50a0685328ec'}
# ..                                    ...
# 176  {'$oid': '662bd9ce440e50a068532998'}
# 177  {'$oid': '662bd9cf440e50a068532999'}
# 178  {'$oid': '662bd9d4440e50a06853299a'}
# 179  {'$oid': '662bdd061a4ee37ee22d2ae4'}
# 180  {'$oid': '662bdd101a4ee37ee22d2ae5'}
#
#                                      uuid user_id  \
# 0    28b3af64-c1a8-417b-9d76-f60b6cd3fe68   user6
# 1    9feb60b1-a421-412b-b2a5-01c9a59b6bb1   user6
# 2    ea1a34a6-2e43-41c5-b75a-5dc61686931e   user6
# 3    78fc77a2-e62f-44d0-a6e8-4b09a7519eac   user6
# 4    ebe273e1-c91c-43d4-ae12-b5a039462d73   user6
# ..                                    ...     ...
# 176  daf4e30c-4c09-48eb-852d-ef3510a679e3   user6
# ...

# %%
#select all the data from the session_id 03ca6510-fada-4fdf-8a29-56a234bb0c51
p1_task = df[df['session_id'] == 'c56bb4c4-d024-4ebe-aaf5-2ab8fd7e68c1']

# %%
#change user_id to user1
p1_task['user_id'] = 'user1'
# Out:
# /var/folders/zm/x5dzdlrs5mlbxrm7z5g6p05r0000gn/T/ipykernel_33295/2182948325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p1_task['user_id'] = 'user1'

# %%
p1_task
# Out:
#                                       _id  \
# 86   {'$oid': '662bd566440e50a06853293e'}
# 87   {'$oid': '662bd569440e50a06853293f'}
# 88   {'$oid': '662bd5aa440e50a068532940'}
# 89   {'$oid': '662bd5da440e50a068532941'}
# 90   {'$oid': '662bd5df440e50a068532942'}
# ..                                    ...
# 176  {'$oid': '662bd9ce440e50a068532998'}
# 177  {'$oid': '662bd9cf440e50a068532999'}
# 178  {'$oid': '662bd9d4440e50a06853299a'}
# 179  {'$oid': '662bdd061a4ee37ee22d2ae4'}
# 180  {'$oid': '662bdd101a4ee37ee22d2ae5'}
#
#                                      uuid user_id  \
# 86   d8c38318-2f3f-471d-a122-0c39f56d3e9a   user1
# 87   66a9b2e4-8ca7-48a6-aca5-2de1b1ae3d45   user1
# 88   ccd007e7-91d7-4f96-83ef-5985e35697c0   user1
# 89   f365e79e-d169-454c-a036-cd9e9fa1b39b   user1
# 90   773b68d0-b3c4-46cc-917c-158ff01dcbf0   user1
# ..                                    ...     ...
# 176  daf4e30c-4c09-48eb-852d-ef3510a679e3   user1
# ...

# %%
# save the data to a csv file
p1_task.to_csv('../data/user-study/processed/p1_task.csv')
